# %%
##EULER METHOD
Function=input('Enter dy/dx : ')
x=float(input('Enter x0 : '))
b=float(input('Enter b : '))
y=float(input('Enter y : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("***************************************")
print("X      Y")
print("**********")
def func(x,y):
    return eval(Function)
   
while(x<=b):

    y1=round(y+h*(func(x,y)),n)
    y=y1
    print(x,y)
    x=round(x+h,n)
# Out:
# Enter dy/dx : x+y
# Enter x0 : 0.00
# Enter b : 1.00
# Enter y : 1.00
# Enter h : .01
# Round up upto how many digit :2
# ***************************************
# X      Y
# **********
# 0.0 1.01
# 0.01 1.02
# 0.02 1.03
# 0.03 1.04
# 0.04 1.05
# 0.05 1.06
# 0.06 1.07
# 0.07 1.08
# 0.08 1.09
# 0.09 1.1
# 0.1 1.11
# 0.11 1.12
# 0.12 1.13
# 0.13 1.14
# 0.14 1.15
# 0.15 1.16
# 0.16 1.17
# 0.17 1.18
# 0.18 1.19
# 0.19 1.2
# 0.2 1.21
# 0.21 1.22
# 0.22 1.23
# 0.23 1.24
# 0.24 1.25
# 0.25 1.26
# 0.26 1.28
# 0.27 1.3
# 0.28 1.32
# 0.29 1.34
# 0.3 1.36
# 0.31 1.38
# 0.32 1.4
# 0.33 1.42
# 0.34 1.44
# 0.35 1.46
# 0.36 1.48
# 0.37 1.5
# 0.38 1.52
# 0.39 1.54
# 0.4 1.56
# 0.41 1.58
# 0.42 1.6
# 0.43 1.62
# 0.44 1.64
# 0.45 1.66
# 0.46 1.68
# 0.47 1.7
# 0.48 1.72
# 0.49 1.74
# 0.5 1.76
# 0.51 1.78
# 0.52 1.8
# 0.53 1.82
# 0.54 1.84
# 0.55 1.86
# 0.56 1.88
# 0.57 1.9
# 0.58 1.92
# 0.59 1.95
# 0.6 1.98
# 0.61 2.01
# 0.62 2.04
# 0.63 2.07
# 0.64 2.1
# 0.65 2.13
# 0.66 2.16
# 0.67 2.19
# 0.68 2.22
# ...

# %%
##Taylor Series METHOD
Func1=input('Enter Dy : ')        ##D=dy/dx
Func2=input('Enter D^2y : ')
x=float(input('Enter x0 : '))
b=float(input('Enter b : '))
y=float(input('Enter y : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("***************************************")
print("X      Y")
print("**********")
def func(x,y):
    return eval(Func1)
def derfunc(x,y):
    return eval(Func2)
   
while(x<=b):

    y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
    y=y1
    print(x,y)
    x=round(x+h,n)
# Out:
# Enter Dy : x+y
# Enter D^2y : 1+x+y
# Enter x0 : 0
# Enter b : 1
# Enter y : 1
# Enter h : 0.1
# Round up upto how many digit :2
# ***************************************
# X      Y
# **********
# 0.0 1.11
# 0.1 1.24
# 0.2 1.4
# 0.3 1.58
# 0.4 1.79
# 0.5 2.04
# 0.6 2.32
# 0.7 2.64
# 0.8 3.01
# 0.9 3.43
# 1.0 3.9

# %%
##Backward Euler METHOD
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
b=float(input('Enter b : '))
y=float(input('Enter y : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("***************************************")
print("X      Y")
print("**********")
def func(x,y):
    return eval(Func1)
   
while(x<=b):

    y1=round(y+h*(func(x+h,y+h*func(x,y))),n)
    y=y1
    print(x,y)
    x=round(x+h,n)
# Out:
# Enter Dy  : x+y
# Enter x0 : 0
# Enter b : 1
# Enter y : 1
# Enter h : 0.1
# Round up upto how many digit :2
# ***************************************
# X      Y
# **********
# 0.0 1.12
# 0.1 1.26
# 0.2 1.43
# 0.3 1.63
# 0.4 1.86
# 0.5 2.13
# 0.6 2.44
# 0.7 2.8
# 0.8 3.21
# 0.9 3.67
# 1.0 4.19

# %%
## Modified Euler METHOD
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
b=float(input('Enter b : '))
y=float(input('Enter y : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("***************************************")
print("X      Y")
print("**********")
def func(x,y):
    return eval(Func1)
   
while(x<=b):

    y1=round(y+h*(func(x+(h/2),y+((h/2)*func(x,y)))),n)
    y=y1
    print(x,y)
    x=round(x+h,n)
# Out:
# Enter Dy  : x+y
# Enter x0 : 0
# Enter b : 1
# Enter y : 1
# Enter h : .1
# Round up upto how many digit :2
# ***************************************
# X      Y
# **********
# 0.0 1.11
# 0.1 1.24
# 0.2 1.4
# 0.3 1.58
# 0.4 1.79
# 0.5 2.04
# 0.6 2.32
# 0.7 2.64
# 0.8 3.01
# 0.9 3.43
# 1.0 3.9

# %%
## HEUN'S METHOD
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
b=float(input('Enter b : '))
y=float(input('Enter y : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("***************************************")
print("X      Y")
print("**********")
def func(x,y):
    return eval(Func1)
   
while(x<=b):
    y1=round(y+h*(func(x,y)+func(x+h,y+h*func(x,y))),n)
    y=y1
    print(x,y)
    x=round(x+h,n)
# Out:
# Enter Dy  : x+y
# Enter x0 : 0
# Enter b : 1
# Enter y : 1
# Enter h : 0.1
# Round up upto how many digit :2
# ***************************************
# X      Y
# **********
# 0.0 1.22
# 0.1 1.51
# 0.2 1.88
# 0.3 2.35
# 0.4 2.94
# 0.5 3.67
# 0.6 4.58
# 0.7 5.7
# 0.8 7.08
# 0.9 8.77
# 1.0 10.83

# %%
##RUNGE KUTTA METHOD
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
b=float(input('Enter b : '))
y=float(input('Enter y : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("***************************************")
print("X      Y")
print("**********")
def func(x,y):
    return eval(Func1)
k1=func(x,y)
k2=func(x+(h/2),y+(k1/2))
k3=func(x+(h/2),y+(k2/2))
k4=func(x+h,y+k3)
while(x<=b):

    y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
    y=y1
    print(x,y)
    x=round(x+h,n)
# Out:
# Enter Dy  : x+y
# Enter x0 : 0
# Enter b : 1
# Enter y : 1
# Enter h : .1
# Round up upto how many digit :2
# ***************************************
# X      Y
# **********
# 0.0 1.18
# 0.1 1.36
# 0.2 1.54
# 0.3 1.72
# 0.4 1.9
# 0.5 2.08
# 0.6 2.26
# 0.7 2.44
# 0.8 2.62
# 0.9 2.8
# 1.0 2.98

# %%
## ADAMS BASHFORTH METHOD
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
y0=float(input('Enter y0 : '))
h=float(input('Enter h : '))
m=int(input(' 1. Euler method\n 2. Taylor Series Method\n 3. Runge Kutta method\n Which method you want to apply for initial three value of a function : '))
n=int(input('Round up upto how many digit :'))
print("***************************************")

def func(x,y):
    return eval(Func1)
x=x-3*h
y=y0
i=-3
if(m==1):
    while(x<=0):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+h*(func(x,y)),n)
        y=y1
        x=round(x+h,n)
elif(m==2):
    Func2=input('Enter D^2y : ')
    def derfunc(x,y):
        return eval(Func2)
   
    while(x<=0):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
        y=y1
        x=round(x+h,n)
else:
    k1=func(x,y)
    k2=func(x+(h/2),y+(k1/2))
    k3=func(x+(h/2),y+(k2/2))
    k4=func(x+h,y+k3)
    while(x<=0):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
        y=y1
        x=round(x+h,n)
l=int(input('choose one method:\n1. Third Order\n2. fourth Order : '))
if(l==1):
    f0=float(input('Enter f(0) : '))
    f_1=float(input('Enter f(-1) : '))
    f_2=float(input('Enter f(-2) : '))
    y1=round(y+((h/12)*(23*f0-16*f_1+5*f_2)),n)
    print('y1 =',y1)
else:
    f0=float(input('Enter f(0) : '))
    f_1=float(input('Enter f(-1) : '))
    f_2=float(input('Enter f(-2) : '))
    f_3=float(input('Enter f(-3) : '))
    y1=round(y+((h/24)*(55*f0-59*f_1+37*f_2-9*f_3)),n)
    print('y1 =',y1)
# Out:
# Enter Dy  : -y*y
# Enter x0 : 0
# Enter y0 : 1
# Enter h : .1
#  1. Euler method
#  2. Taylor Series Method
#  3. Runge Kutta method
#  Which method you want to apply for initial three value of a function : 2
# Round up upto how many digit :8
# ***************************************
# Enter D^2y : 2*y*y*y
# f -3 = -1.0
# f -2 = -0.8281
# f -1 = -0.69676701
# f 0 = -0.594233
# choose one method:
# 1. Third Order
# 2. fourth Order : 1
# Enter f(0) : -0.594233
# Enter f(-1) : -0.69676701
# Enter f(-2) : -0.8281
# y1 = 0.66052597

# %%
## ADAMS-Moultan METHOD
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
y0=float(input('Enter y0 : '))
h=float(input('Enter h : '))
m=int(input(' 1. Euler method\n 2. Taylor Series Method\n 3. Runge Kutta method\n Which method you want to apply for initial three value of a function : '))
n=int(input('Round up upto how many digit :'))
print("****************************************************************************************")

def func(x,y):
    return eval(Func1)
x=x-2*h
y=y0
i=-2
if(m==1):
    while(x<=h):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+h*(func(x,y)),n)
        y=y1
        x=round(x+h,n)
elif(m==2):
    Func2=input('Enter D^2y : ')
    def derfunc(x,y):
        return eval(Func2)
   
    while(x<=h):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
        y=y1
        x=round(x+h,n)
else:
    k1=func(x,y)
    k2=func(x+(h/2),y+(k1/2))
    k3=func(x+(h/2),y+(k2/2))
    k4=func(x+h,y+k3)
    while(x<=h):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
        y=y1
        x=round(x+h,n)
l=int(input('choose one method:\n1. Third Order\n2. fourth Order : '))
if(l==1):
    f1=float(input('Enter f(1) : '))
    f0=float(input('Enter f(0) : '))
    f_1=float(input('Enter f(-1) : '))
    y1=round(y+((h/12)*(5*f1-8*f0-f_1)),n)
    print('y1 =',y1)
else:
    f1=float(input('Enter f(1) : '))
    f0=float(input('Enter f(0) : '))
    f_1=float(input('Enter f(-1) : '))
    f_2=float(input('Enter f(-2) : '))
    y1=round(y+((h/24)*(9*f1+19*f0-5*f_1+f_2)),n)
    print('y1 =',y1)
# Out:
# Enter Dy  : x+y
# Enter x0 : 0
# Enter y0 : 1
# Enter h : 0.1
#  1. Euler method
#  2. Taylor Series Method
#  3. Runge Kutta method
#  Which method you want to apply for initial three value of a function : 3
# Round up upto how many digit :2
# ***************************************
# f -2 = 0.8
# f -1 = 1.04
# f 0 = 1.28
# f 1 = 1.52
# choose one method:
# 1. Third Order
# 2. fourth Order : 1
# Enter f(1) : 1.52
# Enter f(0) : 1.28
# Enter f(-1) : 1.04
# y1 = 1.53

# %%
##Milne-Simpson's Method
print("                                          INITIAL VALUE PROBLEM :")
print("*****************************************************************************************************************")
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
y0=float(input('Enter y0 : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("******************************************************************************************************************")
m=int(input(' 1. Euler method\n 2. Taylor Series Method\n 3. Runge Kutta method\n Which method you want to apply for initial three value of a function : '))


def func(x,y):
    return eval(Func1)
x=x-2*h
y=y0
i=-2
if(m==1):
    while(x<=h):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+h*(func(x,y)),n)
        y=y1
        x=round(x+h,n)
elif(m==2):
    Func2=input('Enter D^2y : ')
    def derfunc(x,y):
        return eval(Func2)
   
    while(x<=h):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
        y=y1
        x=round(x+h,n)
else:
    k1=func(x,y)
    k2=func(x+(h/2),y+(k1/2))
    k3=func(x+(h/2),y+(k2/2))
    k4=func(x+h,y+k3)
    while(x<=h):
        fi=round(func(x,y),n)
        print('f',i,'=',fi)
        i=i+1
        y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
        y=y1
        x=round(x+h,n)
print("******************************************************************************************************************")
f1=float(input('Enter f(1) : '))
f0=float(input('Enter f(0) : '))
f_1=float(input('Enter f(-1) : '))
y1=round(y+((h/3)*(f1+4*f0+f_1)),n)
print('Value of function at y1 =',y1)
# Out:
#                                           INITIAL VALUE PROBLEM :
# *****************************************************************************************************************
# Enter Dy  : x+y
# Enter x0 : 0
# Enter y0 : 1
# Enter h : 0.1
# Round up upto how many digit :2
# ******************************************************************************************************************
#  1. Euler method
#  2. Taylor Series Method
#  3. Runge Kutta method
#  Which method you want to apply for initial three value of a function : 2
# Enter D^2y : 1+x+y
# f -2 = 0.8
# f -1 = 0.99
# f 0 = 1.2
# f 1 = 1.43
# ******************************************************************************************************************
# Enter f(1) : 1.43
# Enter f(0) : 1.2
# Enter f(-1) : 0.99
# Value of function at y1 = 1.73

# %%
##Milne-Simpson's Method
print("                                          INITIAL VALUE PROBLEM :")
print("*****************************************************************************************************************")
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
b=float(input('Enter b : '))
y0=float(input('Enter y0 : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("******************************************************************************************************************")
Type_of_IVP=int(input(' 1. Single step Method\n 2. Multistep Method\n Which type of initial value problem you want to go for : '))
print("******************************************************************************************************************")

if(Type_of_IVP==1):
    T=int(input(' 1. Euler method\n 2. Taylor Series Method\n 3. Modified Euler Method\n 4. Backward Euler Method\n 5. Heuns Method\n 6. Runge kutta Method\n  Which method among the above you want to use to calculate the value of function at required point : '))
    print('************************')
    print('X         Y')
    print('************************')
    if(T==1):
        while(x<=b):
            y1=round(y+h*(func(x,y)),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
    if(T==2):
        def derfunc(x,y):
            return eval(Func2)
        while(x<=b):
            y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
    if(T==3):
        while(x<=b):
            y1=round(y+h*(func(x+(h/2),y+((h/2)*func(x,y)))),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
        
    if(T==4):
        while(x<=b):
            y1=round(y+h*(func(x+h,y+h*func(x,y))),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
        
    if(T==5):
        while(x<=b):
            y1=round(y+h*(func(x,y)+func(x+h,y+h*func(x,y))),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
        
    else:
        k1=func(x,y)
        k2=func(x+(h/2),y+(k1/2))
        k3=func(x+(h/2),y+(k2/2))
        k4=func(x+h,y+k3)
        while(x<=b):
            y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
else:
    p=float(input('Enter 1 for Predictor Method\nEnter 2 for corrector Method\n'))
    print("******************************************************************************************************************")

    m=int(input(' 1. Euler method\n 2. Taylor Series Method\n 3. Runge Kutta method\n Which method you want to apply for initial three value of a function : '))
    print("******************************************************************************************************************")

    if(p==1):
        x=x-3*h
        y=y0
        i=-3
        if(m==1):
            print('Derivatives value using Euler method')
            while(x<=0):
                fi=round(func(x,y),n)
                print('f',i,'=',fi)
                i=i+1
                y1=round(y+h*(func(x,y)),n)
                y=y1
                x=round(x+h,n)
        elif(m==2):
            print('Derivatives value using Taylor method')
            Func2=input('Enter D^2y : ')
            def derfunc(x,y):
                return eval(Func2)
            while(x<=0):
                fi=round(func(x,y),n)
                print('f',i,'=',fi)
                i=i+1
                y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
                y=y1
                x=round(x+h,n)
        else:
            print('Derivatives value using Runge Kutta Method')
            k1=func(x,y)
            k2=func(x+(h/2),y+(k1/2))
            k3=func(x+(h/2),y+(k2/2))
            k4=func(x+h,y+k3)
            while(x<=0):
                fi=round(func(x,y),n)
                print('f',i,'=',fi)
                i=i+1
                y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
                y=y1
                x=round(x+h,n)
        print("******************************************************************************************************************")
        l=int(input('choose one method:\n1. Third Order\n2. fourth Order : '))
        if(l==1):
            f0=float(input('Enter f(0) : '))
            f_1=float(input('Enter f(-1) : '))
            f_2=float(input('Enter f(-2) : '))
            y1=round(y+((h/12)*(23*f0-16*f_1+5*f_2)),n)
            print('y1 =',y1)
        else:
            f0=float(input('Enter f(0) : '))
            f_1=float(input('Enter f(-1) : '))
            f_2=float(input('Enter f(-2) : '))
            f_3=float(input('Enter f(-3) : '))
            y1=round(y+((h/24)*(55*f0-59*f_1+37*f_2-9*f_3)),n)
            print('y1 =',y1)
    else:
        c=float(input('Which Correcter method:\n 1.Adam-Moultan method\n 2. Mile simpsons method'))
        print("******************************************************************************************************************")
        if(c==1):
            x=x-2*h
            y=y0
            i=-2
            if(m==1):
                print('Derivatives value using Euler method')
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+h*(func(x,y)),n)
                    y=y1
                    x=round(x+h,n)
            elif(m==2):
                print('Derivatives value using Taylormethod')
                Func2=input('Enter D^2y : ')
                def derfunc(x,y):
                    return eval(Func2)
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
                    y=y1
                    x=round(x+h,n)
            else:
                print('Derivatives value using Runge kutta method')
                k1=func(x,y)
                k2=func(x+(h/2),y+(k1/2))
                k3=func(x+(h/2),y+(k2/2))
                k4=func(x+h,y+k3)
                while(x<=h):
                        fi=round(func(x,y),n)
                        print('f',i,'=',fi)
                        i=i+1
                        y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
                        y=y1
                        x=round(x+h,n)
                l=int(input('choose one method:\n1. Third Order\n2. fourth Order : '))
                if(l==1):
                    f1=float(input('Enter f(1) : '))
                    f0=float(input('Enter f(0) : '))
                    f_1=float(input('Enter f(-1) : '))
                    y1=round(y+((h/12)*(5*f1-8*f0-f_1)),n)
                    print('y1 =',y1)
                else:
                    f1=float(input('Enter f(1) : '))
                    f0=float(input('Enter f(0) : '))
                    f_1=float(input('Enter f(-1) : '))
                    f_2=float(input('Enter f(-2) : '))
                    y1=round(y+((h/24)*(9*f1+19*f0-5*f_1+f_2)),n)
                    print("******************************************************************************************************************")                        
                    print('y1 =',y1)
        else:
            x=x-2*h
            y=y0
            i=-2
            if(m==1):
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+h*(func(x,y)),n)
                    y=y1
                    x=round(x+h,n)
            elif(m==2):
                Func2=input('Enter D^2y : ')
                def derfunc(x,y):
                    return eval(Func2)
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
                    y=y1
                    x=round(x+h,n)
            else:
                k1=func(x,y)
                k2=func(x+(h/2),y+(k1/2))
                k3=func(x+(h/2),y+(k2/2))
                k4=func(x+h,y+k3)
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
                    y=y1
                    x=round(x+h,n)
                print("******************************************************************************************************************")
                f1=float(input('Enter f(1) : '))
                f0=float(input('Enter f(0) : '))
                f_1=float(input('Enter f(-1) : '))
                y1=round(y+((h/3)*(f1+4*f0+f_1)),n)
                print('Value of function at y1 =',y1)
# Out:
#                                           INITIAL VALUE PROBLEM :
# *****************************************************************************************************************
# Enter Dy  : x+y
# Enter x0 : 0
# Enter b : 1
# Enter y0 : 1
# Enter h : .1
# Round up upto how many digit :3
# ******************************************************************************************************************
#  1. Single step Method
#  2. Multistep Method
#  Which type of initial value problem you want to go for : 2
# ******************************************************************************************************************
# Enter 1 for Predictor Method
# Enter 2 for corrector Method
# 1
# ******************************************************************************************************************
#  1. Euler method
#  2. Taylor Series Method
#  3. Runge Kutta method
#  Which method you want to apply for initial three value of a function : 3
# ...

# %%
##Milne-Simpson's Method
print("                                          INITIAL VALUE PROBLEM :")
print("*****************************************************************************************************************")
Func1=input('Enter Dy  : ')        ##D=dy/dx
x=float(input('Enter x0 : '))
b=float(input('Enter b : '))
y0=float(input('Enter y0 : '))
h=float(input('Enter h : '))
n=int(input('Round up upto how many digit :'))
print("******************************************************************************************************************")
Type_of_IVP=int(input(' 1. Single step Method\n 2. Multistep Method\n Which type of initial value problem you want to go for : '))
if(Type_of_IVP==1):
    T=int(input(' 1. Euler method\n 2. Taylor Series Method\n 3. Modified Euler Method\n 4. Backward Euler Method\n 5. Heuns Method\n 6. Runge kutta Method\n  Which method among the above you want to use to calculate the value of function at required point : '))
    print('************************')
    print('X         Y')
    print('************************')
    if(T==1):
        while(x<=b):
            y1=round(y+h*(func(x,y)),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
    if(T==2):
        def derfunc(x,y):
            return eval(Func2)
        while(x<=b):
            y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
    if(T==3):
        while(x<=b):
            y1=round(y+h*(func(x+(h/2),y+((h/2)*func(x,y)))),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
        
    if(T==4):
        while(x<=b):
            y1=round(y+h*(func(x+h,y+h*func(x,y))),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
        
    if(T==5):
        while(x<=b):
            y1=round(y+h*(func(x,y)+func(x+h,y+h*func(x,y))),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
        
    else:
        k1=func(x,y)
        k2=func(x+(h/2),y+(k1/2))
        k3=func(x+(h/2),y+(k2/2))
        k4=func(x+h,y+k3)
        while(x<=b):
            y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
            y=y1
            print(x,y)
            x=round(x+h,n)
else:
    p=float(input('Enter 1 for Predictor Method\nEnter 2 for corrector Method\n'))
    m=int(input(' 1. Euler method\n 2. Taylor Series Method\n 3. Runge Kutta method\n Which method you want to apply for initial three value of a function : '))

    if(p==1):
        x=x-3*h
        y=y0
        i=-3
        if(m==1):
            while(x<=0):
                fi=round(func(x,y),n)
                print('f',i,'=',fi)
                i=i+1
                y1=round(y+h*(func(x,y)),n)
                y=y1
                x=round(x+h,n)
        elif(m==2):
            Func2=input('Enter D^2y : ')
            def derfunc(x,y):
                return eval(Func2)
            while(x<=0):
                fi=round(func(x,y),n)
                print('f',i,'=',fi)
                i=i+1
                y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
                y=y1
                x=round(x+h,n)
        else:
            k1=func(x,y)
            k2=func(x+(h/2),y+(k1/2))
            k3=func(x+(h/2),y+(k2/2))
            k4=func(x+h,y+k3)
            while(x<=0):
                fi=round(func(x,y),n)
                print('f',i,'=',fi)
                i=i+1
                y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
                y=y1
                x=round(x+h,n)
        l=int(input('choose one method:\n1. Third Order\n2. fourth Order : '))
        if(l==1):
            f0=float(input('Enter f(0) : '))
            f_1=float(input('Enter f(-1) : '))
            f_2=float(input('Enter f(-2) : '))
            y1=round(y+((h/12)*(23*f0-16*f_1+5*f_2)),n)
            print('y1 =',y1)
        else:
            f0=float(input('Enter f(0) : '))
            f_1=float(input('Enter f(-1) : '))
            f_2=float(input('Enter f(-2) : '))
            f_3=float(input('Enter f(-3) : '))
            y1=round(y+((h/24)*(55*f0-59*f_1+37*f_2-9*f_3)),n)
            print('y1 =',y1)
    else:
        c=float(input('Which Correcter method:\n 1.Adam-Moultan method\n 2. Mile simpsons method'))
        if(c==1):
            x=x-2*h
            y=y0
            i=-2
            if(m==1):
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+h*(func(x,y)),n)
                    y=y1
                    x=round(x+h,n)
            elif(m==2):
                Func2=input('Enter D^2y : ')
                def derfunc(x,y):
                    return eval(Func2)
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
                    y=y1
                    x=round(x+h,n)
            else:
                k1=func(x,y)
                k2=func(x+(h/2),y+(k1/2))
                k3=func(x+(h/2),y+(k2/2))
                k4=func(x+h,y+k3)
                while(x<=h):
                        fi=round(func(x,y),n)
                        print('f',i,'=',fi)
                        i=i+1
                        y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
                        y=y1
                        x=round(x+h,n)
                l=int(input('choose one method:\n1. Third Order\n2. fourth Order : '))
                if(l==1):
                    f1=float(input('Enter f(1) : '))
                    f0=float(input('Enter f(0) : '))
                    f_1=float(input('Enter f(-1) : '))
                    y1=round(y+((h/12)*(5*f1-8*f0-f_1)),n)
                    print('y1 =',y1)
                else:
                    f1=float(input('Enter f(1) : '))
                    f0=float(input('Enter f(0) : '))
                    f_1=float(input('Enter f(-1) : '))
                    f_2=float(input('Enter f(-2) : '))
                    y1=round(y+((h/24)*(9*f1+19*f0-5*f_1+f_2)),n)
                    print("******************************************************************************************************************")                        
                    print('y1 =',y1)
        else:
            x=x-2*h
            y=y0
            i=-2
            if(m==1):
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+h*(func(x,y)),n)
                    y=y1
                    x=round(x+h,n)
            elif(m==2):
                Func2=input('Enter D^2y : ')
                def derfunc(x,y):
                    return eval(Func2)
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+h*(func(x,y))+((h*h/2)*(derfunc(x,y))),n)
                    y=y1
                    x=round(x+h,n)
            else:
                k1=func(x,y)
                k2=func(x+(h/2),y+(k1/2))
                k3=func(x+(h/2),y+(k2/2))
                k4=func(x+h,y+k3)
                while(x<=h):
                    fi=round(func(x,y),n)
                    print('f',i,'=',fi)
                    i=i+1
                    y1=round(y+((h/6)*(k1+2*(k2+k3)+k4)),n)
                    y=y1
                    x=round(x+h,n)
                print("******************************************************************************************************************")
                f1=float(input('Enter f(1) : '))
                f0=float(input('Enter f(0) : '))
                f_1=float(input('Enter f(-1) : '))
                y1=round(y+((h/3)*(f1+4*f0+f_1)),n)
                print('Value of function at y1 =',y1)
